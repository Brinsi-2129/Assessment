# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/Priya-tops/Tops-Assessment-Data/main/Data%20Analytics/finance_economics_dataset.csv"

df = pd.read_csv(url)

df.head()
# Out:
#          Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 0  2000-01-01   Dow Jones     2128.75      2138.48     2143.70    2100.55
# 1  2000-01-02     S&P 500     2046.82      2036.18     2082.83    2009.53
# 2  2000-01-03   Dow Jones     1987.92      1985.26     2022.28    1978.37
# 3  2000-01-04   Dow Jones     4625.02      4660.47     4665.26    4595.46
# 4  2000-01-05     S&P 500     1998.18      1982.18     2044.31    1966.44
#
#    Trading Volume  GDP Growth (%)  Inflation Rate (%)  Unemployment Rate (%)  \
# 0         2670411           -0.37                6.06                   6.10
# 1       690220415            3.19                4.95                   6.62
# 2       315284661            5.54                9.13                   2.60
# 3        13098297           10.00                3.77                   2.20
# 4       385306746            1.53                2.20                   8.20
#
# ...

# %%
#Que 1
df.shape
# Out:
# (3000, 24)

# %%
#Que 2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date                                   3000 non-null   object
#  1   Stock Index                            3000 non-null   object
#  2   Open Price                             3000 non-null   float64
#  3   Close Price                            3000 non-null   float64
#  4   Daily High                             3000 non-null   float64
#  5   Daily Low                              3000 non-null   float64
#  6   Trading Volume                         3000 non-null   int64
#  7   GDP Growth (%)                         3000 non-null   float64
#  8   Inflation Rate (%)                     3000 non-null   float64
#  9   Unemployment Rate (%)                  3000 non-null   float64
# ...

# %%
#Que 3
df['Stock Index'].nunique()
# Out:
# 3

# %%
#Que 4
df['Date'] = pd.to_datetime(df['Date'])

print("Start Date:", df['Date'].min())
print("End Date:", df['Date'].max())
# Out:
# Start Date: 2000-01-01 00:00:00
# End Date: 2008-03-18 00:00:00

# %%
#Que 5
df.isnull().sum()
# Out:
# Date                                     0
# Stock Index                              0
# Open Price                               0
# Close Price                              0
# Daily High                               0
# Daily Low                                0
# Trading Volume                           0
# GDP Growth (%)                           0
# Inflation Rate (%)                       0
# Unemployment Rate (%)                    0
# Interest Rate (%)                        0
# Consumer Confidence Index                0
# Government Debt (Billion USD)            0
# Corporate Profits (Billion USD)          0
# Forex USD/EUR                            0
# Forex USD/JPY                            0
# Crude Oil Price (USD per Barrel)         0
# Gold Price (USD per Ounce)               0
# Real Estate Index                        0
# Retail Sales (Billion USD)               0
# Bankruptcy Rate (%)                      0
# Mergers & Acquisitions Deals             0
# ...

# %%
#Que 6
print((df['Open Price'] < 0).sum())
print((df['Close Price'] < 0).sum())
print((df['Trading Volume'] < 0).sum())
print((df['Gold Price (USD per Ounce)'] < 0).sum())
print((df['Crude Oil Price (USD per Barrel)'] < 0).sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
#Que 7
df['GDP Growth (%)'].describe()
# Out:
# count    3000.000000
# mean        2.608903
# std         4.287337
# min        -5.000000
# 25%        -1.012500
# 50%         2.725000
# 75%         6.242500
# max        10.000000
# Name: GDP Growth (%), dtype: float64

# %%
#Que 8
(df['Trading Volume'] == 0).sum()
# Out:
# np.int64(0)

# %%
#Que 9
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Que 10
sns.boxplot(data=df[['GDP Growth (%)',
                     'Gold Price (USD per Ounce)',
                     'Crude Oil Price (USD per Barrel)']])
plt.show()

# %%
#Que 11
df['Inflation Rate (%)'].describe()
# Out:
# count    3000.000000
# mean        5.096830
# std         2.910513
# min         0.010000
# 25%         2.607500
# 50%         5.110000
# 75%         7.600000
# max        10.000000
# Name: Inflation Rate (%), dtype: float64

# %%
#Que 12
df['Unemployment Rate (%)'].mean()
# Out:
# np.float64(8.663786666666667)

# %%
#Que 13
df.groupby('Stock Index')['Trading Volume'].mean().sort_values(ascending=False)
# Out:
# Stock Index
# S&P 500      5.145193e+08
# Dow Jones    4.991151e+08
# NASDAQ       4.959921e+08
# Name: Trading Volume, dtype: float64

# %%
#Que 14
df['Stock Index'].value_counts()
# Out:
# Stock Index
# S&P 500      1036
# NASDAQ       1007
# Dow Jones     957
# Name: count, dtype: int64

# %%
#Que 15
df[['Inflation Rate (%)','Interest Rate (%)']].corr()
# Out:
#                     Inflation Rate (%)  Interest Rate (%)
# Inflation Rate (%)            1.000000           0.005733
# Interest Rate (%)             0.005733           1.000000

# %%
#Que 16
df['Consumer Confidence Index'].mean()
# Out:
# np.float64(85.036)

# %%
#Que 17
df.std(numeric_only=True).sort_values(ascending=False)
# Out:
# Trading Volume                           2.859004e+08
# Government Debt (Billion USD)            8.524231e+03
# Consumer Spending (Billion USD)          4.203706e+03
# Retail Sales (Billion USD)               2.898714e+03
# Corporate Profits (Billion USD)          1.429981e+03
# Open Price                               1.151863e+03
# Daily Low                                1.151835e+03
# Close Price                              1.151784e+03
# Daily High                               1.151683e+03
# Gold Price (USD per Ounce)               4.921777e+02
# Real Estate Index                        1.146013e+02
# Crude Oil Price (USD per Barrel)         3.784706e+01
# Venture Capital Funding (Billion USD)    2.872259e+01
# Consumer Confidence Index                2.022483e+01
# Forex USD/JPY                            2.011135e+01
# Mergers & Acquisitions Deals             1.430134e+01
# GDP Growth (%)                           4.287337e+00
# ...

# %%
#Que 18
df['Gold Price (USD per Ounce)'].max()
# Out:
# 2499.66

# %%
#Que 19
df.loc[df['Crude Oil Price (USD per Barrel)'].idxmax(), 'Date']
# Out:
# Timestamp('2001-11-22 00:00:00')

# %%
#Que 20
df['Corporate Profits (Billion USD)'].mean()
# Out:
# np.float64(2553.7563333333333)

# %%
#Que 1
negative = (df['GDP Growth (%)'] < 0).sum()
total = len(df)

(negative / total) * 100
# Out:
# np.float64(31.566666666666666)

# %%
#Que 2
df[['Inflation Rate (%)','Interest Rate (%)']].corr()
# Out:
#                     Inflation Rate (%)  Interest Rate (%)
# Inflation Rate (%)            1.000000           0.005733
# Interest Rate (%)             0.005733           1.000000

# %%
#Que 3
df[['Unemployment Rate (%)',
    'Consumer Spending (Billion USD)']].corr()
# Out:
#                                  Unemployment Rate (%)  \
# Unemployment Rate (%)                         1.000000
# Consumer Spending (Billion USD)               0.018786
#
#                                  Consumer Spending (Billion USD)
# Unemployment Rate (%)                                   0.018786
# Consumer Spending (Billion USD)                         1.000000

# %%
#Que 4
df[['Corporate Profits (Billion USD)',
    'Consumer Confidence Index']].corr()
# Out:
#                                  Corporate Profits (Billion USD)  \
# Corporate Profits (Billion USD)                         1.000000
# Consumer Confidence Index                               0.018008
#
#                                  Consumer Confidence Index
# Corporate Profits (Billion USD)                   0.018008
# Consumer Confidence Index                         1.000000

# %%
#Que 5
plt.plot(df['Date'], df['Crude Oil Price (USD per Barrel)'])
plt.show()

# %%
#Que 6
df[['Gold Price (USD per Ounce)','Close Price']].corr()
# Out:
#                             Gold Price (USD per Ounce)  Close Price
# Gold Price (USD per Ounce)                    1.000000    -0.014544
# Close Price                                  -0.014544     1.000000

# %%
#Que 7
df[['Government Debt (Billion USD)',
    'Consumer Confidence Index']].corr()
# Out:
#                                Government Debt (Billion USD)  \
# Government Debt (Billion USD)                        1.00000
# Consumer Confidence Index                           -0.03637
#
#                                Consumer Confidence Index
# Government Debt (Billion USD)                   -0.03637
# Consumer Confidence Index                        1.00000

# %%
#Que 8
df[['Retail Sales (Billion USD)',
    'GDP Growth (%)']].corr()
# Out:
#                             Retail Sales (Billion USD)  GDP Growth (%)
# Retail Sales (Billion USD)                    1.000000       -0.014288
# GDP Growth (%)                               -0.014288        1.000000

# %%
#Que 9
df[['Close Price',
    'Consumer Spending (Billion USD)']].corr()
# Out:
#                                  Close Price  Consumer Spending (Billion USD)
# Close Price                         1.000000                         0.000376
# Consumer Spending (Billion USD)     0.000376                         1.000000

# %%
#Que 10
df[['Close Price',
    'Consumer Spending (Billion USD)']].corr()
# Out:
#                                  Close Price  Consumer Spending (Billion USD)
# Close Price                         1.000000                         0.000376
# Consumer Spending (Billion USD)     0.000376                         1.000000

# %%
#Que 11
df.groupby('Stock Index')['Close Price'].mean().sort_values(ascending=False)
# Out:
# Stock Index
# Dow Jones    3004.456447
# NASDAQ       2985.905015
# S&P 500      2955.286052
# Name: Close Price, dtype: float64

# %%
#Que 12
df[['Interest Rate (%)',
    'Unemployment Rate (%)']].corr()
# Out:
#                        Interest Rate (%)  Unemployment Rate (%)
# Interest Rate (%)               1.000000               0.018004
# Unemployment Rate (%)           0.018004               1.000000

# %%
#Que 13
df[['Consumer Confidence Index',
    'Bankruptcy Rate (%)']].corr()
# Out:
#                            Consumer Confidence Index  Bankruptcy Rate (%)
# Consumer Confidence Index                   1.000000            -0.016313
# Bankruptcy Rate (%)                        -0.016313             1.000000

# %%
#Que 14
df.corr(numeric_only=True)['Close Price'].sort_values(ascending=False)
# Out:
# Close Price                              1.000000
# Daily High                               0.999821
# Daily Low                                0.999820
# Open Price                               0.999688
# Retail Sales (Billion USD)               0.049370
# Bankruptcy Rate (%)                      0.029380
# Venture Capital Funding (Billion USD)    0.021414
# Interest Rate (%)                        0.020434
# Trading Volume                           0.016283
# Consumer Confidence Index                0.013482
# Corporate Profits (Billion USD)          0.008797
# Mergers & Acquisitions Deals             0.002637
# Crude Oil Price (USD per Barrel)         0.002563
# Consumer Spending (Billion USD)          0.000376
# Unemployment Rate (%)                   -0.001907
# Government Debt (Billion USD)           -0.007332
# Inflation Rate (%)                      -0.007972
# Real Estate Index                       -0.008639
# GDP Growth (%)                          -0.012748
# ...

# %%
#Que 15
df[['Unemployment Rate (%)',
    'Corporate Profits (Billion USD)']].corr()
# Out:
#                                  Unemployment Rate (%)  \
# Unemployment Rate (%)                         1.000000
# Corporate Profits (Billion USD)               0.008292
#
#                                  Corporate Profits (Billion USD)
# Unemployment Rate (%)                                   0.008292
# Corporate Profits (Billion USD)                         1.000000
